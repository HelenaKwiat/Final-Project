# %%
import pandas as pd
bat2019 = pd.read_csv('Batting2019.csv', sep = ',', error_bad_lines=False)
pitch2019 = pd.read_csv('Pitching2019.csv', sep = ',', error_bad_lines=False)
field2019 = pd.read_csv('Fielding2019.csv', sep = ',', error_bad_lines=False)
field2019 = field2019.drop(['Team'], axis = 1)

# %%
# bat2019['Team'].unique()
# Out:
# array(['Dodgers', 'Angels', 'Brewers', 'Nationals', 'Rays', 'Royals',
#        'White Sox', 'Athletics', 'Cardinals', 'Mets', 'Twins', 'Cubs',
#        'Astros', 'Phillies', 'Braves', 'Orioles', 'Blue Jays', 'Rangers',
#        'Mariners', 'Indians', 'Padres', 'Yankees', 'Red Sox',
#        'Diamondbacks', 'Reds', 'Pirates', 'Tigers', 'Rockies', 'Marlins',
#        'Giants', '- - -'], dtype=object)

# %%
# print(bat2019.columns)
# print(pitch2019.columns)
# print(field2019.columns)
batandField = pd.merge(bat2019, field2019, on =['Name'], how = 'outer' )
batFieldandPitch = pd.merge(batandField, pitch2019, on =['Team', 'Name'], how='outer')
batFieldandPitch = batFieldandPitch.fillna(0)

offMin = batFieldandPitch['Off'].min()
offMax = batFieldandPitch['Off'].max()
defxMin = batFieldandPitch['Def_x'].min()
defxMax = batFieldandPitch['Def_x'].max()
defyMin = batFieldandPitch['Def_y'].min()
defyMax = batFieldandPitch['Def_y'].max()

batFieldandPitch['normalize_Off'] = ((batFieldandPitch['Off']-offMin) / (offMax-offMin)) * (10) 
batFieldandPitch['normalize_Def_y'] = ((batFieldandPitch['Def_y']-defyMin) / (defyMax-defyMin)) * (10) 
batFieldandPitch['normalize_Def_y'] = batFieldandPitch['normalize_Def_y'] * -1
batFieldandPitch['normalize_Def_x'] = ((batFieldandPitch['Def_x']-defxMin) / (defxMax-defxMin)) * (10) 
batFieldandPitch['normalize_Def_x'] = batFieldandPitch['normalize_Def_x'] * -1

# NewDef = (batFieldandPitch[['normalize_Def_x', 'Team']].groupby('Team', as_index=False).mean()['normalize_Def_x'] + batFieldandPitch[['normalize_Def_y', 'Team']].groupby('Team', as_index=False).mean()['normalize_Def_y'])/2
# print( batFieldandPitch[['normalize_Off', 'Team']].groupby('Team', as_index=False).sum()['normalize_Off'])
# print( batFieldandPitch[['normalize_Def_y', 'Team']].groupby('Team', as_index=False).sum()['normalize_Def_y'])
# print(batFieldandPitch[['normalize_Def_x', 'Team']].groupby('Team', as_index=False).sum()['normalize_Def_x']) 

# batFieldandPitch.head([batFieldandPitch[['normalize_Off', 'Team']].groupby('Team', as_index=False).sum()['Team'], batFieldandPitch[['normalize_Off', 'Team']].groupby('Team', as_index=False).sum()['normalize_Off'] + batFieldandPitch[['normalize_Def_y', 'Team']].groupby('Team', as_index=False).sum()['normalize_Def_y'] + batFieldandPitch[['normalize_Def_x', 'Team']].groupby('Team', as_index=False).sum()['normalize_Def_x']])

newStat = pd.concat([batFieldandPitch[['normalize_Off', 'Team']].groupby('Team', as_index=False).mean()['Team'], batFieldandPitch[['normalize_Off', 'Team']].groupby('Team', as_index=False).mean()['normalize_Off'] + (batFieldandPitch[['normalize_Def_y', 'Team']].groupby('Team', as_index=False).mean()['normalize_Def_y'] + batFieldandPitch[['normalize_Def_x', 'Team']].groupby('Team', as_index=False).mean()['normalize_Def_x'])/2], axis=1)

newStat = newStat.drop(newStat.index[[0,1]])
newStat['teamID'] =  ['LAA', 'HOU', 'OAK', 'TOR', 'ATL', 'MIL', 'STL', 'CHC', 'ARI', 'LAD', 'SFG', 'CLE', 'SEA', 'MIA', 'NYM', 'WSN', 'BAL', 'SDP', 'PHI', 'PIT', 'TEX', 'TBR', 'BOS', 'CIN', 'COL', 'KCR', 'DET', 'MIN', 'CHW', 'NYY']
print(newStat)




# print(batFieldandPitch.columns)
# Out:
#             Team         0 teamID
# 2         Angels -2.475038    LAA
# 3         Astros -1.644265    HOU
# 4      Athletics -2.622888    OAK
# 5      Blue Jays -2.465678    TOR
# 6         Braves -1.576181    ATL
# 7        Brewers -2.259636    MIL
# 8      Cardinals -2.021505    STL
# 9           Cubs -1.887865    CHC
# 10  Diamondbacks -2.616274    ARI
# 11       Dodgers -1.406490    LAD
# 12        Giants -3.990495    SFG
# 13       Indians -2.159041    CLE
# 14      Mariners  0.284702    SEA
# 15       Marlins -3.416112    MIA
# 16          Mets -1.624040    NYM
# 17     Nationals -1.356567    WSN
# 18       Orioles -2.118856    BAL
# 19        Padres -3.382708    SDP
# 20      Phillies -2.475562    PHI
# 21       Pirates -2.723374    PIT
# 22       Rangers -2.230116    TEX
# 23          Rays -1.840001    TBR
# 24       Red Sox -1.980470    BOS
# 25          Reds -2.872230    CIN
# 26       Rockies -3.887529    COL
# 27        Royals -2.104804    KCR
# 28        Tigers -3.011625    DET
# 29         Twins -1.935697    MIN
# 30     White Sox -1.629118    CHW
# 31       Yankees -1.863479    NYY
# Index(['Name', 'Team', 'G_x', 'PA', 'HR', 'R', 'RBI', 'SB', 'BB%', 'K%', 'ISO',
#        'BABIP_x', 'AVG', 'OBP', 'SLG', 'wOBA', 'wRC+', 'BsR', 'Off', 'Def_x',
#        'WAR_x', 'playerid_x', 'Pos', 'Inn', 'rSZ', 'rCERA', 'rSB', 'rGDP',
#        'rARM', 'rGFP', 'rPM', 'rTS', 'DRS', 'BIZ', 'Plays', 'RZR', 'OOZ',
#        'FSR', 'FRM', 'ARM', 'DPR', 'RngR', 'ErrR', 'UZR', 'UZR/150', 'Def_y',
#        'playerid_y', 'W', 'L', 'SV', 'G_y', 'GS', 'IP', 'K/9', 'BB/9', 'HR/9',
#        'BABIP_y', 'LOB%', 'GB%', 'HR/FB', 'ERA', 'FIP', 'xFIP', 'WAR_y',
#        'playerid', 'normalize_Off', 'normalize_Def_y', 'normalize_Def_x'],
#       dtype='object')

# %%
#Download the Lahman data
from pybaseball.lahman import *
teams = teams()
teams2016 = teams.loc[teams['yearID']==2016]
print(teams2016.columns)
# wins = pd.merge(newStat, teams2016[['teamID', 'wins', '']])
print(teams)
# Out:
# Index(['yearID', 'lgID', 'teamID', 'franchID', 'divID', 'Rank', 'G', 'Ghome',
#        'W', 'L', 'DivWin', 'WCWin', 'LgWin', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'HBP', 'SF', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E', 'DP', 'FP',
#        'name', 'park', 'attendance', 'BPF', 'PPF', 'teamIDBR',
#        'teamIDlahman45', 'teamIDretro'],
#       dtype='object')
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  ...  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN   20   10  ...
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN   19    9  ...
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN   10   19  ...
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN    7   12  ...
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN   16   17  ...
# 5       1871  NaN    PH1      PNA   NaN     1   28    NaN   21    7  ...
# 6       1871  NaN    RC1      ROK   NaN     9   25    NaN    4   21  ...
# 7       1871  NaN    TRO      TRO   NaN     6   29    NaN   13   15  ...
# 8       1871  NaN    WS3      OLY   NaN     4   32    NaN   15   15  ...
# 9       1872  NaN    BL1      BLC   NaN     2   58    NaN   35   19  ...
# 10      1872  NaN    BR1      ECK   NaN     9   29    NaN    3   26  ...
# 11      1872  NaN    BR2      BRA   NaN     6   37    NaN    9   28  ...
# 12      1872  NaN    BS1      BNA   NaN     1   48    NaN   39    8  ...
# 13      1872  NaN    CL1      CFC   NaN     7   22    NaN    6   16  ...
# 14      1872  NaN    MID      MAN   NaN     8   24    NaN    5   19  ...
# 15      1872  NaN    NY2      NNA   NaN     3   56    NaN   34   20  ...
# 16      1872  NaN    PH1      PNA   NaN     4   47    NaN   30   14  ...
# 17      1872  NaN    TRO      TRO   NaN     5   25    NaN   15   10  ...
# 18      1872  NaN    WS3      OLY   NaN    10    9    NaN    2    7  ...
# 19      1872  NaN    WS4      NAT   NaN    11   11    NaN    0   11  ...
# 20      1873  NaN    BL1      BLC   NaN     3   57    NaN   34   22  ...
# 21      1873  NaN    BL4      MAR   NaN     9    6    NaN    0    6  ...
# 22      1873  NaN    BR2      BRA   NaN     6   55    NaN   17   37  ...
# 23      1873  NaN    BS1      BNA   NaN     1   60    NaN   43   16  ...
# 24      1873  NaN    ELI      RES   NaN     8   23    NaN    2   21  ...
# 25      1873  NaN    NY2      NNA   NaN     4   53    NaN   29   24  ...
# 26      1873  NaN    PH1      PNA   NaN     5   52    NaN   28   23  ...
# 27      1873  NaN    PH2      PWS   NaN     2   53    NaN   36   17  ...
# 28      1873  NaN    WS5      WBL   NaN     7   39    NaN    8   31  ...
# 29      1874  NaN    BL1      BLC   NaN     8   47    NaN    9   38  ...
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ...  ...  ...
# 2805    2016   NL    ARI      ARI     W     4  162   81.0   69   93  ...
# 2806    2016   NL    ATL      ATL     E     5  161   81.0   68   93  ...
# 2807    2016   AL    BAL      BAL     E     2  162   81.0   89   73  ...
# 2808    2016   AL    BOS      BOS     E     1  162   81.0   93   69  ...
# 2809    2016   AL    CHA      CHW     C     4  162   81.0   78   84  ...
# 2810    2016   NL    CHN      CHC     C     1  162   81.0  103   58  ...
# 2811    2016   NL    CIN      CIN     C     5  162   81.0   68   94  ...
# 2812    2016   AL    CLE      CLE     C     1  161   80.0   94   67  ...
# 2813    2016   NL    COL      COL     W     3  162   81.0   75   87  ...
# 2814    2016   AL    DET      DET     C     2  161   81.0   86   75  ...
# 2815    2016   AL    HOU      HOU     W     3  162   81.0   84   78  ...
# 2816    2016   AL    KCA      KCR     C     3  162   81.0   81   81  ...
# 2817    2016   AL    LAA      ANA     W     4  162   81.0   74   88  ...
# 2818    2016   NL    LAN      LAD     W     1  162   81.0   91   71  ...
# 2819    2016   NL    MIA      FLA     E     3  161   80.0   79   82  ...
# 2820    2016   NL    MIL      MIL     C     4  162   81.0   73   89  ...
# 2821    2016   AL    MIN      MIN     C     5  162   81.0   59  103  ...
# 2822    2016   AL    NYA      NYY     E     4  162   81.0   84   78  ...
# 2823    2016   NL    NYN      NYM     E     2  162   81.0   87   75  ...
# 2824    2016   AL    OAK      OAK     W     5  162   81.0   69   93  ...
# 2825    2016   NL    PHI      PHI     E     4  162   81.0   71   91  ...
# 2826    2016   NL    PIT      PIT     C     3  162   81.0   78   83  ...
# 2827    2016   NL    SDN      SDP     W     5  162   81.0   68   94  ...
# 2828    2016   AL    SEA      SEA     W     2  162   81.0   86   76  ...
# 2829    2016   NL    SFN      SFG     W     2  162   81.0   87   75  ...
# 2830    2016   NL    SLN      STL     C     2  162   81.0   86   76  ...
# 2831    2016   AL    TBA      TBD     E     5  162   81.0   68   94  ...
# 2832    2016   AL    TEX      TEX     W     1  162   81.0   95   67  ...
# 2833    2016   AL    TOR      TOR     E     2  162   81.0   89   73  ...
# 2834    2016   NL    WAS      WSN     E     1  162   81.0   95   67  ...
#
#          DP     FP                           name  \
# 0       NaN  0.838           Boston Red Stockings
# 1       NaN  0.829        Chicago White Stockings
# 2       NaN  0.814         Cleveland Forest Citys
# 3       NaN  0.803           Fort Wayne Kekiongas
# 4       NaN  0.839               New York Mutuals
# 5       NaN  0.845         Philadelphia Athletics
# 6       NaN  0.821          Rockford Forest Citys
# 7       NaN  0.845                 Troy Haymakers
# 8       NaN  0.850            Washington Olympics
# 9       NaN  0.829             Baltimore Canaries
# 10      NaN  0.798              Brooklyn Eckfords
# 11      NaN  0.810             Brooklyn Atlantics
# 12      NaN  0.874           Boston Red Stockings
# 13      NaN  0.823         Cleveland Forest Citys
# 14      NaN  0.806          Middletown Mansfields
# 15      NaN  0.867               New York Mutuals
# 16      NaN  0.858         Philadelphia Athletics
# 17      NaN  0.862                 Troy Haymakers
# 18      NaN  0.786            Washington Olympics
# 19      NaN  0.765           Washington Nationals
# 20      NaN  0.855             Baltimore Canaries
# 21      NaN  0.768            Baltimore Marylands
# 22      NaN  0.820             Brooklyn Atlantics
# 23      NaN  0.837           Boston Red Stockings
# 24      NaN  0.787            Elizabeth Resolutes
# 25      NaN  0.821               New York Mutuals
# 26      NaN  0.842         Philadelphia Athletics
# 27      NaN  0.847            Philadelphia Whites
# 28      NaN  0.840           Washington Blue Legs
# 29      NaN  0.819             Baltimore Canaries
# ...     ...    ...                            ...
# 2805  143.0  0.983           Arizona Diamondbacks
# 2806  134.0  0.983                 Atlanta Braves
# 2807  165.0  0.987              Baltimore Orioles
# 2808  139.0  0.987                 Boston Red Sox
# 2809  148.0  0.984              Chicago White Sox
# 2810  116.0  0.983                   Chicago Cubs
# 2811  142.0  0.983                Cincinnati Reds
# 2812  126.0  0.985              Cleveland Indians
# 2813  148.0  0.982               Colorado Rockies
# 2814  148.0  0.987                 Detroit Tigers
# 2815  135.0  0.987                 Houston Astros
# 2816  134.0  0.984             Kansas City Royals
# 2817  148.0  0.983  Los Angeles Angels of Anaheim
# 2818  101.0  0.986            Los Angeles Dodgers
# 2819  137.0  0.985                  Miami Marlins
# 2820  145.0  0.978              Milwaukee Brewers
# 2821  172.0  0.979                Minnesota Twins
# 2822  116.0  0.985               New York Yankees
# 2823  138.0  0.985                  New York Mets
# 2824  152.0  0.984              Oakland Athletics
# 2825  142.0  0.984          Philadelphia Phillies
# 2826  172.0  0.982             Pittsburgh Pirates
# 2827  165.0  0.982               San Diego Padres
# 2828  158.0  0.985               Seattle Mariners
# 2829  136.0  0.988           San Francisco Giants
# 2830  169.0  0.983            St. Louis Cardinals
# 2831  129.0  0.984                 Tampa Bay Rays
# 2832  190.0  0.984                  Texas Rangers
# 2833  144.0  0.986              Toronto Blue Jays
# 2834  142.0  0.988           Washington Nationals
#
#                                    park  attendance  BPF  PPF  teamIDBR  \
# 0                   South End Grounds I         NaN  103   98       BOS
# 1               Union Base-Ball Grounds         NaN  104  102       CHI
# 2          National Association Grounds         NaN   96  100       CLE
# 3                        Hamilton Field         NaN  101  107       KEK
# 4              Union Grounds (Brooklyn)         NaN   90   88       NYU
# 5              Jefferson Street Grounds         NaN  102   98       ATH
# 6     Agricultural Society Fair Grounds         NaN   97   99       ROK
# 7                    Haymakers' Grounds         NaN  101  100       TRO
# 8                      Olympics Grounds         NaN   94   98       OLY
# 9                        Newington Park         NaN  106  102       BAL
# 10                        Union Grounds         NaN   87   96       ECK
# 11                   Capitoline Grounds         NaN  115  122       BRA
# 12                  South End Grounds I         NaN  105  100       BOS
# 13         National Association Grounds         NaN   96  100       CLE
# 14               Mansfield Club Grounds         NaN   98  103       MAN
# 15             Union Grounds (Brooklyn)         NaN   93   92       NYU
# 16             Jefferson Street Grounds         NaN  102  100       ATH
# 17                   Haymakers' Grounds         NaN  101  100       TRO
# 18                     Olympics Grounds         NaN   94   98       OLY
# 19                    Nationals Grounds         NaN  129  141       NAT
# 20                       Newington Park         NaN  101  102       BAL
# 21                       Newington Park         NaN   77   99       MAR
# 22                        Union Grounds         NaN   90   94       BRA
# 23                  South End Grounds I         NaN  106  100       BOS
# 24                  Waverly Fairgrounds         NaN   92  103       RES
# 25             Union Grounds (Brooklyn)         NaN   98   96       NYU
# 26             Jefferson Street Grounds         NaN  108  105       ATH
# 27             Jefferson Street Grounds         NaN  103  101       PHI
# 28                     Olympics Grounds         NaN   96  102       WAS
# 29                       Newington Park         NaN  102  104       BAL
# ...                                 ...         ...  ...  ...       ...
# 2805                        Chase Field   2036216.0  107  108       ARI
# 2806                       Turner Field   2020914.0  102  104       ATL
# 2807        Oriole Park at Camden Yards   2172344.0  101  101       BAL
# 2808                     Fenway Park II   2955434.0  108  106       BOS
# 2809                U.S. Cellular Field   1746293.0   96   97       CHW
# 2810                      Wrigley Field   3232420.0   95   93       CHC
# 2811           Great American Ball Park   1894085.0   99  100       CIN
# 2812                  Progressive Field   1591667.0  110  109       CLE
# 2813                        Coors Field   2602524.0  117  117       COL
# 2814                      Comerica Park   2493859.0  101  101       DET
# 2815                   Minute Maid Park   2306623.0   90   89       HOU
# 2816                   Kauffman Stadium   2557712.0  105  106       KCR
# 2817           Angel Stadium of Anaheim   3016142.0   95   95       LAA
# 2818                     Dodger Stadium   3703312.0   93   92       LAD
# 2819                       Marlins Park   1712417.0   93   93       MIA
# 2820                        Miller Park   2314614.0   99   99       MIL
# 2821                       Target Field   1963912.0   96   98       MIN
# 2822                 Yankee Stadium III   3063405.0  105  105       NYY
# 2823                         Citi Field   2789602.0  102  102       NYM
# 2824                      O.co Coliseum   1521506.0   90   91       OAK
# 2825                 Citizens Bank Park   1915144.0   91   93       PHI
# 2826                           PNC Park   2249201.0  100  101       PIT
# 2827                         Petco Park   2351422.0   99   99       SDP
# 2828                       Safeco Field   2267928.0   98   97       SEA
# 2829                          AT&T Park   3365256.0  103  102       SFG
# 2830                  Busch Stadium III   3444490.0  100   99       STL
# 2831                    Tropicana Field   1286163.0   93   94       TBR
# 2832      Rangers Ballpark in Arlington   2710402.0  106  105       TEX
# 2833                      Rogers Centre   3392099.0  111  110       TOR
# 2834                     Nationals Park   2481938.0  100   98       WSN
#
#       teamIDlahman45  teamIDretro
# 0                BS1          BS1
# 1                CH1          CH1
# 2                CL1          CL1
# 3                FW1          FW1
# 4                NY2          NY2
# 5                PH1          PH1
# 6                RC1          RC1
# 7                TRO          TRO
# 8                WS3          WS3
# 9                BL1          BL1
# 10               BR1          BR1
# 11               BR2          BR2
# 12               BS1          BS1
# 13               CL1          CL1
# 14               MID          MID
# 15               NY2          NY2
# 16               PH1          PH1
# 17               TRO          TRO
# 18               WS3          WS3
# 19               WS4          WS4
# 20               BL1          BL1
# 21               BL4          BL4
# 22               BR2          BR2
# 23               BS1          BS1
# 24               ELI          ELI
# 25               NY2          NY2
# 26               PH1          PH1
# 27               PH2          PH2
# 28               WS5          WS5
# 29               BL1          BL1
# ...              ...          ...
# 2805             ARI          ARI
# 2806             ATL          ATL
# 2807             BAL          BAL
# 2808             BOS          BOS
# 2809             CHA          CHA
# 2810             CHN          CHN
# 2811             CIN          CIN
# 2812             CLE          CLE
# 2813             COL          COL
# 2814             DET          DET
# 2815             HOU          HOU
# 2816             KCA          KCA
# 2817             ANA          ANA
# 2818             LAN          LAN
# 2819             FLO          MIA
# 2820             ML4          MIL
# 2821             MIN          MIN
# 2822             NYA          NYA
# 2823             NYN          NYN
# 2824             OAK          OAK
# 2825             PHI          PHI
# 2826             PIT          PIT
# 2827             SDN          SDN
# 2828             SEA          SEA
# 2829             SFN          SFN
# 2830             SLN          SLN
# 2831             TBA          TBA
# 2832             TEX          TEX
# 2833             TOR          TOR
# 2834             MON          WAS
#
# [2835 rows x 48 columns]

# %%
# Out:
#                Name       Team   G  PA  HR   R  RBI  SB     BB%      K%  ...  \
# 0    Cody Bellinger    Dodgers  18  78   9  22   23   3  12.8 %  11.5 %  ...
# 1        Mike Trout     Angels  13  54   5  10   12   1  29.6 %   7.4 %  ...
# 2  Christian Yelich    Brewers  17  78   8  17   22   3  14.1 %  14.1 %  ...
# 3    Anthony Rendon  Nationals  14  63   6  18   17   0   9.5 %  12.7 %  ...
# 4    Austin Meadows       Rays  15  64   6   8   17   2  12.5 %  21.9 %  ...
#
#      AVG    OBP    SLG   wOBA  wRC+  BsR   Off  Def  WAR  playerid
# 0  0.433  0.513  0.925  0.577   264 -0.1  16.7 -0.4  1.9     15998
# 1  0.382  0.593  0.882  0.563   272  0.5  11.8  2.4  1.6     10155
# 2  0.354  0.449  0.785  0.490   202  1.0  11.4 -0.1  1.4     11477
# 3  0.400  0.460  0.873  0.534   230  0.9  11.7 -1.5  1.2     12861
# 4  0.357  0.438  0.732  0.474   211  0.5   9.1 -0.4  1.1     15672
#
# [5 rows x 22 columns]

# %%
# pitch2019.head()
# Out:
#             Name       Team  W  L  SV  G  GS    IP    K/9  BB/9  HR/9  BABIP  \
# 0   Matthew Boyd     Tigers  1  1   0  3   3  17.1  15.06  3.12  0.00  0.389
# 1   Max Scherzer  Nationals  1  2   0  4   4  27.0  11.67  1.67  0.67  0.344
# 2   Carlos Rodon  White Sox  2  2   0  4   4  22.0  11.86  3.68  0.00  0.281
# 3  Luis Castillo       Reds  1  1   0  4   4  24.2  11.68  4.74  0.00  0.184
# 4   Jose Berrios      Twins  2  1   0  4   4  27.1   9.22  1.65  0.99  0.185
#
#      LOB%     GB%   HR/FB   ERA   FIP  xFIP  WAR  playerid
# 0  71.4 %  26.5 %   0.0 %  2.60  1.01  2.62  1.1     15440
# 1  70.9 %  48.5 %   9.5 %  3.33  2.29  2.78  1.0      3137
# 2  61.5 %  41.1 %   0.0 %  3.27  1.87  3.74  1.0     16137
# 3  83.3 %  58.7 %   0.0 %  1.46  2.37  3.36  0.9     15689
# 4  83.3 %  43.3 %  11.1 %  2.30  3.18  3.60  0.8     14168

# %%
# field2019.head()
# Out:
#                Name Team Pos    Inn  rSZ  rCERA  rSB  rGDP  rARM  rGFP  ...  \
# 0      Buster Posey  SFG   C   99.0    1    0.0  1.0   NaN   NaN     1  ...
# 1    Ramon Laureano  OAK  CF  153.2    0    NaN  NaN   NaN   4.0     1  ...
# 2     J.T. Realmuto  PHI   C  117.0    0    0.0  1.0   NaN   NaN     1  ...
# 3  Martin Maldonado  KCR   C  115.0    1    0.0  1.0   NaN   NaN     2  ...
# 4    Harrison Bader  STL  CF  117.0    0    NaN  NaN   NaN   1.0    -1  ...
#
#    FSR  FRM  ARM  DPR  RngR  ErrR  UZR  UZR/150  Def  playerid
# 0  NaN  1.7  NaN  NaN   NaN   NaN  NaN      NaN  3.5      9166
# 1  NaN  NaN  3.9  NaN  -0.5  -0.2  3.3     47.3  3.5     17128
# 2  NaN  1.1  NaN  NaN   NaN   NaN  NaN      NaN  3.1     11739
# 3  NaN  1.1  NaN  NaN   NaN   NaN  NaN      NaN  3.0      6887
# 4  NaN  NaN  1.7  NaN   1.6  -0.6  2.7     44.9  2.9     18030
#
# [5 rows x 27 columns]

# %%
# print(batFieldandPitch[['Off','Def_x', 'Def_y']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-c4ec65e246f1> in <module>()
# ----> 1 print(batFieldandPitch[['off','Def_x', 'Def_y']])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2922                 key = list(key)
#    2923             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2924                                                    raise_missing=True)
#    2925
#    2926         # take() does not accept boolean indexers
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1355         else:
#    1356             try:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1159         self._validate_read_indexer(keyarr, indexer,
#    1160                                     o._get_axis_number(axis),
# -> 1161                                     raise_missing=raise_missing)
#    1162         return keyarr, indexer
#    1163
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1250             if not(self.name == 'loc' and not raise_missing):
#    1251                 not_found = list(set(key) - set(ax))
# -> 1252                 raise KeyError("{} not in index".format(not_found))
#    1253
#    1254             # we skip the warning on Categorical/Interval
#
# KeyError: "['off'] not in index"
